# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.append('../../lib/')

# %%
from analysis import *

# %%
loaded_json = analysis.universal_data_loader('clean_tweets_without_duplicates_v8.json')

# %%
print(len(loaded_json[0]))
# Out:
# 1

# %%
all_tweets = analysis.create_tweet_list_from_loaded_json(loaded_json)

# %%
# Get the first 100 tweets
all_tweets = all_tweets[:100]

# %%
print(len(all_tweets))
# Out:
# 100

# %%
clean_all_tweets = analysis.clean_tweets(all_tweets)
# Out:
# [nltk_data] Downloading package stopwords to /home/gabe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gabe/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/gabe/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
common_words = analysis.get_most_common_words(clean_all_tweets)

# %%
analysis.create_bar_chart(common_words, 10, "Most common words in 100 most confident from v4", "words", "number of tweets with word", "tweets_that_are_most_confident_v8.png")

# %%
analysis.create_word_cloud(clean_all_tweets, "tweets_that_are_most_confident_wordcloud_v8.png")
