# %%
import sys
sys.path.append('../../lib/')

# %%
from analysis import *
import random
import glob
import shutil

# %%
tweets_list_possable_bad = analysis.create_tweet_list_from_loaded_json(analysis.universal_data_loader("posable_bad_tweets.json"))
tweets_list_good = analysis.create_tweet_list_from_loaded_json(analysis.universal_data_loader("300_random_users_first_tweet.json"))
tweets_list_false_positives = analysis.create_tweet_list_from_loaded_json(analysis.universal_data_loader("false_postives_from_v3_ivory.json"))
seed_user_good_tweets = analysis.create_tweet_list_from_loaded_json(analysis.universal_data_loader("100_random_tweets_from_seed_users.json"))

# %%
print("bad_tweet_list:", len(tweets_list_possable_bad))
print("good_tweet_list:", len(tweets_list_good))
print("false_positive_list:", len(tweets_list_false_positives))
print("seed_user_good_tweets:", len(seed_user_good_tweets))
# Out:
# bad_tweet_list: 168
# good_tweet_list: 240
# false_positive_list: 131
# seed_user_good_tweets: 100

# %%
tweets_list_possable_bad_tmp = []
for tweet in tweets_list_possable_bad:
    # Get just the tweet's text
    tweet_text = analysis.get_tweet_text(tweet)

    # Remove all url's from tweet and replace with 'URL'
    tweet_text = analysis.replace_urls(tweet_text)

    # Replace all @username
    tweet_text = analysis.replace_mentions(tweet_text)
	
	# Excape any quotes in the tweet
    tweet_text = tweet_text.replace('"', '""')
    
    # Replace the tweet text
    tweet["text"] = tweet_text
    
    tweets_list_possable_bad_tmp.append(tweet)


tweets_list_good_tmp = []
# Remove all the tweets that are not in english
for tweet in tweets_list_good:
        # Get just the tweet's text
    tweet_text = analysis.get_tweet_text(tweet)

    # Remove all url's from tweet and replace with 'URL'
    tweet_text = analysis.replace_urls(tweet_text)

    # Replace all @username
    tweet_text = analysis.replace_mentions(tweet_text)
    
    # If the tweet is not in english, remove it
    try:
        if not analysis.is_english(tweet_text):
            print("Removing tweet:", tweet_text)
            # tweets_list_good.remove(tweet)
        else:
            # Excape any quotes in the tweet
            tweet_text = tweet_text.replace('"', '""')
            
            # Replace the tweet text
            tweet["text"] = tweet_text
            
            # Add the tweet to the list
            tweets_list_good_tmp.append(tweet)
    except:
        # If the tweet is not in english, remove it
        # tweets_list_good.remove(tweet)
        print("Removing tweet:", tweet_text)

tweets_list_false_positives_tmp = [] 
for tweet in tweets_list_false_positives:
        # Get just the tweet's text
    tweet_text = analysis.get_tweet_text(tweet)

    # Remove all url's from tweet and replace with 'URL'
    tweet_text = analysis.replace_urls(tweet_text)

    # Replace all @username
    tweet_text = analysis.replace_mentions(tweet_text)
    try:
        # If the tweet is not in english, remove it
        if not analysis.is_english(tweet_text):
            print("Removing tweet:", tweet_text)
            # tweets_list_false_positives.remove(tweet)
        else:
            # Excape any quotes in the tweet
            tweet_text = tweet_text.replace('"', '""')
            
            # Replace the tweet text
            tweet["text"] = tweet_text
            
            # Add the tweet to the list
            tweets_list_false_positives_tmp.append(tweet)
    except:
        # If the tweet is not in english, remove it
        # tweets_list_false_positives.remove(tweet)
        print("Removing tweet:", tweet_text)

seed_user_good_tweets_tmp = []
for tweet in seed_user_good_tweets:
        # Get just the tweet's text
    tweet_text = analysis.get_tweet_text(tweet)

    # Remove all url's from tweet and replace with 'URL'
    tweet_text = analysis.replace_urls(tweet_text)

    # Replace all @username
    tweet_text = analysis.replace_mentions(tweet_text)
    try:
        # If the tweet is not in english, remove it
        if not analysis.is_english(tweet_text):
            print("Removing tweet:", tweet_text)
            # seed_user_good_tweets.remove(tweet)
        else:
            # Excape any quotes in the tweet
            tweet_text = tweet_text.replace('"', '""')
            
            # Replace the tweet text
            tweet["text"] = tweet_text
            
            # Add the tweet to the list
            seed_user_good_tweets_tmp.append(tweet)
    except:
        # If the tweet is not in english, remove it
        # seed_user_good_tweets.remove(tweet)
        print("Removing tweet:", tweet_text)

print("bad_tweet_list:", len(tweets_list_possable_bad_tmp))
print("good_tweet_list:", len(tweets_list_good_tmp))
print("false_positive_list:", len(tweets_list_false_positives_tmp))
print("seed_user_good_tweets:", len(seed_user_good_tweets_tmp))
# Out:
# Removing tweet: RT {{MENTION}}: »Om fem år er der ikke nogen, der ejer sin egen bil mere, og de biler, vi køber nu, er de sidste,« siger ⁦⁦{{MENTION}}⁩. Læs…
# Removing tweet: .{{MENTION}} #Boris4Xmasno1
# Removing tweet: RT {{MENTION}}: Get your congitive test.
# Removing tweet: RT {{MENTION}}: Presidente {{MENTION}} Res#2370 ANLA que autoriza extracción de especies de aves, mariposas y ranas para zoo cría es un abs…
# Removing tweet: #BELvsUSA #howard
# Removing tweet: {{MENTION}} {{MENTION}} Congratulations!
# Removing tweet: {{MENTION}} uomo vero, oltre che persona professionale e preparata!!!
# Removing tweet: {{MENTION}} Sentido Rio?
# Removing tweet: burcuozberk'in fotoğrafı {{URL}}
# Removing tweet: Congrats {{URL}}
# Removing tweet: {{MENTION}} eu num gosto de crepúsculo não!
# Removing tweet: PS Vitaから投稿テストです。
# Removing tweet: Siiiiii jaja {{MENTION}}
# Removing tweet: RT {{MENTION}}: Okula giderken bilboardlarımız karşısınıza çıkabilir!
#
# Özgür, özerk ve demokratik üniversite için tüm bileşenler olarak…
# Removing tweet: {{MENTION}} Exemplo de hoje, orgulho de amanhã. ♥
# Removing tweet: {{MENTION}} {{URL}}
# Removing tweet: Vandaag 25 januari: Dag van de ode aan de zorg! Breng jij een ode uit via social media met #odeaandezorg, aan een zorgcollega die een hart onder de riem verdient, aan een specifieke zorgorganisatie, of aan de zorg in het algemeen?! {{URL}}
# Removing tweet: 興味深いお話だった。
# Removing tweet: Göz yaşlarımın doğum günü kulu olur mu?
# Removing tweet: {{MENTION}} {{MENTION}} My man!
# Removing tweet: Bangsat!!
# Removing tweet: Go God! {{URL}}
# Removing tweet: {{MENTION}} wkwk cheon
# Removing tweet: RT {{MENTION}}: PAUL JOURNET - La forêt des mal-aimés #lapresseplus {{URL}}
# Removing tweet: Kenapa babi jalannya selalu menunduk hayooo???ada yang tau???
# Removing tweet: exit dulu twibiboys. chibi chibi, ha ha ha ha ha ha. see you babay;*&lt;33
# Removing tweet: {{MENTION}} {{MENTION}} Hans-Günter Brünker (Volt) "Dabei muss zwangsläufig auch die Frage gestellt werden, inwiefern die Kassenvielfalt beibehalten werden soll." ({{URL}}) Ich glaube, bei Euch herrscht da noch keine Einigkeit ;-)
# Removing tweet: אהוד ברק אולי תתחיל לסתום את הפה שלך! אתה בן אדם המייצר שינאה ומתוסכל אל דאגה נסתדר בלעדיך.
# Removing tweet: RT {{MENTION}}: to aki no col com o {{MENTION}}
# Removing tweet: {{MENTION}} Haha eu amo uma banda &lt;3
# Removing tweet: Good night😴😴✌
# Removing tweet: {{MENTION}} {{MENTION}} Congratulations Olya!
# Removing tweet: RT {{MENTION}}: ／
# ㊗アニメ新情報解禁！
# #お待たせしました地獄楽
# フォロー＆RTキャンペーン🎉
# ＼
#
# #賀来ゆうじ 先生の直筆イラスト色紙を抽選で1名様にプレゼント！
#
# ■応募方法
# ①@jplus_jigokurakをフォロー
# ②この投稿をリツイート…
# Removing tweet: Ganmamg style quetema mas chistoso ese video
# Removing tweet: 平均年齢約35歳 {{URL}}
# Removing tweet: モイ！パソコンからツイキャスで配信中 {{URL}}
# Removing tweet: {{URL}} &lt;-- ufo attacks!
# Removing tweet: {{URL}}
# Removing tweet: {{MENTION}} Não, desista
# Removing tweet: RT {{MENTION}}: Universitarios crean un robot para buscar personas en zonas de desastre {{URL}}
# Removing tweet: {{MENTION}} {{MENTION}} pour toi #RolexbyTeufeurS
# Removing tweet: Hay una trabajadora de casa particular de subse y el sacoweas del cuico de Torrealba dice que al gobierno de Boric le falta calle.
# Son weones hasta cuando le dan servida la opción de no ser weones
# Removing tweet: {{URL}} Ranitidine
# Removing tweet: Kandy Korn! :) {{URL}}
# Removing tweet: Лечение кариеса Студенческая {{URL}}
# Removing tweet: {{MENTION}} Glad to hear you’re okay bud!!!
# Removing tweet: Wordle 227 3/6*
#
# ⬛⬛🟨⬛🟨
# 🟩⬛⬛🟩🟩
# 🟩🟩🟩🟩🟩
# Removing tweet: La trinitat impossible {{URL}} {{MENTION}}
# Removing tweet: Siento que estoy en julio de 2020 otra vez, que pesadilla.
# Removing tweet: {{MENTION}} happy birthday!
# Removing tweet: {{URL}}
# Wow.
# Removing tweet: {{MENTION}} 🤣🤣🤣 {{URL}}
# Removing tweet: {{MENTION}} {{MENTION}} Valencia, PA! {{URL}}
# Removing tweet: {{MENTION}} お仲間がいて心強いです(^-^)v。朝ツラいのはしんどいですね。うちのとこも旦那は不定休で、休みが読めなくて予定立てれないっすよ(&gt;_&lt;)。お互いドンマイですね。
# Removing tweet: vagoty203011
# Removing tweet: {{MENTION}} I'm game
# Removing tweet: {{MENTION}} ليه تجاهل ٣٠ يونيو؟
# Removing tweet: Hello {{MENTION}} , comment ça se passe pour l'URL du tracker ? les fichier torrent sont toujours en .is et donc impossible de s'annoncer sur le tracker :(
# Removing tweet: {{MENTION}} mumbai, india
# Removing tweet: {{URL}}
# Removing tweet: {{MENTION}} roflmao
# Removing tweet: AAAAH, morri. tem DUAS SEMANAS qe eu to sem net vei SEMATA. então, vou reaprender a usaar o computador e daqui um tempo eu volto bjs
# Removing tweet: {{MENTION}} {{URL}}
# Removing tweet: {{MENTION}} Al chavocho
# Removing tweet: {{MENTION}} 😱😵‍💫
# Removing tweet: Antiques Atlas - Large Antique Royal Worcester Blush Ivory Vase {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Large Antique Royal Worcester Ivory Pot Pourri {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Pair Of Antique Royal Worcester Blush Ivory Vases {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Large Antique Royal Worcester Blush Ivory Vase {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Antique Royal Worcester Blush Ivory Pedestal Vase {{URL}} via {{MENTION}}
# Removing tweet: RT {{MENTION}}: Antiques Atlas - Pair Of Antique Royal Worcester Blush Ivory Vases {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Pair Of Antique Royal Worcester Blush Ivory Vases {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Antique Royal Worcester Blush Ivory Pedestal Vase. {{URL}} via {{MENTION}}
# Removing tweet: Antiques Atlas - Pair Of Antique Royal Worcester Blush Ivory Vases {{URL}} via {{MENTION}}
# Removing tweet: Meiji Japanese cane ca. 1890 illegal if  hb5578 passes #ivory #antique {{MENTION}} {{MENTION}} {{MENTION}} {{URL}}
# Removing tweet: Antique ivory {{URL}}
# Removing tweet: dugong ivory ( antique) {{URL}}
# Removing tweet: dugong ivory (antique) {{URL}}
# Removing tweet: {{URL}} via {{MENTION}} #vintage #ebay #1952 #ivorybakelitetelephone #ivory #bakelite
# Removing tweet: TWO VINTAGE CHINA PLATES WITH VIEW OF OLD ENGLAND 1930S BY WOOD IVORY WARE {{URL}}
# Removing tweet: Vintage Anheuser-Busch Clydesdale Holiday Beer Mug - Budweiser Tankard Stein 1989 Ceramarte {{URL}} {{URL}}
# Removing tweet: {{URL}}
# Removing tweet: Американский пехотинец в Корее, воруженный снайперским самозарядным карабином 1944 M3 Carbine с инфракрасным ночным прицелом. {{URL}}
# Removing tweet: {{URL}}
# Removing tweet: A #vintage Model metal Train #Locomotive.
# #modern #decoration {{URL}}
# Removing tweet: RT {{MENTION}}: 30 августа 1873 открыта Земля Франца-Иосифа – входит в состав Приморского р-на Архангельской обл. Территория заказника «Зем…
# Removing tweet: {{URL}} via {{MENTION}} #etsysale #etsycybersale #CyberMonday
# Removing tweet: RT {{MENTION}}: Марк Шагал. «Русская деревня». 1929 г. Холст, масло. {{URL}}
# Removing tweet: RT {{MENTION}}: Шпалера "Осень"
# Серия "Времена года. Гротески"
# Автор картона: Перино дель Вага (Пьеро Буонаккорси)
# Фландрия, середина…
# Removing tweet: RT {{MENTION}}: Вымирающая специальность. Шотландский трубочист. Великобритания. Прибл. 1860г. {{URL}}
# Removing tweet: RT {{MENTION}}: Альфред Сислей. «Церковь в Море». 1893 г. Холст, масло. Музей изящных искусств. Руан. Франция. {{URL}}
# Removing tweet: RT {{MENTION}}: В этот день в 1873 г. экспедиция под руководством Юлиуса Пайера и Карла Вейпрехта открыла Землю Франца-Иосифа. {{URL}}
# Removing tweet: Французская пехота конца 18 - начала 19 века. {{URL}}
# Removing tweet: #cybersale #etsycybersale
# Removing tweet: Уличный рынок в восточном районе Индианаполиса, САСШ, август 1908. Фото из коллекции Э. Клоппер. {{URL}}
# Removing tweet: Аббатство Кайлмор(Kylemore Abbey), Ирландия. {{URL}}
# Removing tweet: View our Autumn Fine Sale catalogue here: {{URL}}
# #gorringes #fineart #antiques #auction {{URL}}
# Removing tweet: RT {{MENTION}}: Питер Пауль Рубенс. «Благовещение». Деталь. Между 1608 и 1628 гг. Холст, масло. Дом-музей Рубенса. Антверпен. {{URL}}
# bad_tweet_list: 168
# good_tweet_list: 175
# false_positive_list: 116
# seed_user_good_tweets: 82

# %%
tweet_list = tweets_list_possable_bad_tmp + tweets_list_good_tmp + tweets_list_false_positives_tmp + seed_user_good_tweets_tmp

# %%
# Map tweet ids to user discriptions
tweet_id_to_user_description = {}
# Load json file
with open("tweets_with_images.json") as json_file:
	user_description_to_id = json.load(json_file)
for user_description in user_description_to_id["tweets"]:
	# try: 
	tweet_id_to_user_description[user_description["data"]["id"]] = analysis.replace_urls(user_description['includes']["users"][0]["description"])
	# except:
	# 	print("Error:", user_description["data"]["id"])

# %%
print("Total tweets:", len(tweet_list))
print(analysis.get_tweet_text(tweet_list[1]))
# Out:
# Total tweets: 541
# Vintage Hammer Brand Two Blade Pocket Knife Folding Black Silver Red Celluloid 1940s {{URL}} {{URL}}

# %%
# Search for the word http in tweet_list
for tweet in tweet_list:
	tweet_text = analysis.get_tweet_text(tweet)
	if "http" in tweet_text:
		print("Found http in tweet:", tweet_text)

# %%
# Get all image paths from the image folder
image_id_to_path = {}
for image in glob.glob("images/*"):
    # Get the image id
	image_id = image.split("/")[1]
	# Remove everything after _x.jpg
	image_id = image_id.split("_")[0]
 
	# Check if the image id is in the image_id_to_path dictionary
	if image_id in image_id_to_path:
		image_id_to_path[image_id].append(image)
	else:
		# Add the image id to the image path
		image_id_to_path[image_id] = [image]

# %%
# Set the seed
random.seed(42)

# Shuffle the tweet list
random.shuffle(tweet_list)

# Write to CSV
with open("tweets.csv", "w") as tweetcsv:
    tweetcsv.write('"tweet_id","tweet_text","user_description","label"\n')
    with open("tweet_ids_to_fake_ids.csv", "w") as idmapcsv:
        idmapcsv.write('fake_id","tweet_id"\n')
        for fake_id, tweet in enumerate(tweet_list):

            tweet_text = analysis.get_tweet_text(tweet)

            # Rename to image file to the fake id
            if analysis.get_tweet_id(tweet) in image_id_to_path:
                image_paths = image_id_to_path[analysis.get_tweet_id(tweet)]
                counter = 0
                for image_path in image_paths:
                    # Get extension
                    extention = image_path.split(".")[-1]
                    shutil.copy(image_path, "images_fake_ids/" + str(fake_id) + "_" + str(counter) + "." + extention)
                    counter += 1
                    
            # Write to tweet csv
            try:
                tweetcsv.write('"' + str(fake_id) + '","' + tweet_text + '","' + tweet_id_to_user_description[analysis.get_tweet_id(tweet)] + '"\n')
            except:
                print("Error:", analysis.get_tweet_id(tweet))
            # Write to the map csv
            try:
                idmapcsv.write('"' + str(fake_id) + '","' +
                        str(analysis.get_tweet_id(tweet)) + '" \n')
            except:
                idmapcsv.write('"' + str(fake_id) + '","' + "No tweet id" + '" \n')
# Out:
# Error: 1197089880620359681
# Error: 1462435902349791236
# Error: 972067962155827201
# Error: 976933459754135552
# Error: 1364237335781642240
# Error: 819691561852145664
# Error: 1136588515024801792
# Error: 1445029595804311553
# Error: 713465908757405697
# Error: 1153998426507534336
# Error: 1074289144619298816
# Error: 1285642121681215488
# Error: 1322596141809192962
# Error: 1146336528517554177
# Error: 1486580954168643585
# Error: 929290070967902208
# Error: 1462542675928879107
# Error: 1442162374413258752
# Error: 1486548390070550531
# Error: 1312001018452992002
# Error: 511889286661427200
# Error: 1297618364412628992
