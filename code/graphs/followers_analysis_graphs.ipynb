# %%
import json
import matplotlib.pyplot as plt

# %%
# Read in json file
file_location = "../../data/followers_analysis.json"
with open(file_location) as f:
	data = json.load(f)

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "tweets_with_search_words": [
#         {
#             "user": "1132988843609808899",
#             "tweet": "RT @NFTGUYY: HUGE BORED APE GIVEAWAY \ud83d\ude80\ud83d\udea8\n\nI AM GIVING AWAY 3 MUTANT @BoredApeYC NFTS! #NFTGiveaway\n \n\ud83d\udcb0Floor price = 6 ETH (each)\ud83d\udcb0\n($28.300)\u2026",
#             "id": "1460365657120325635"
#         },
#         {
#             "user": "1132988843609808899",
#             "tweet": "RT @donkey_dao: 3 x Donkey NFT Giveaway\n\nHEE-HAAW! We are celebrating the opening of our Discord! \n\nPresale Spots are now available. (350 P\u2026",
#             "id": "1458699832533655553"
#         },
#         {
#             "user": "1132988843609808899",
#             "tweet": "RT @cake__work: GM! To celebrate the upcoming presale for MIMO, I am giving away a sockpass that will get you access to the round 2 presale\u2026",
#             "id": "1458415513441292288"
#         },
#         {
# ...
